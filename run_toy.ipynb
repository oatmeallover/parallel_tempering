# %% [markdown]
# # Computing Tempered Energy

# %% [markdown]
# We aim to implement a parallel tempering scheme for annealed MCMC as per Du et al.'s [2024 paper](https://arxiv.org/pdf/2302.11552) on compositional generation with energy-based diffusion. In order to implement parallel tempering into the sampling regime of annealed MCMC, we aim to evaluate the difference between true tempered energy and our approximations.
#
# Training follows standard DDPM noise-matching objective

# %% [markdown]
# ### Setup

# %%
from src.eval import plot_temperature_triptych
from src.sample import ddpm_tsr_swapped
import torch
import numpy as np

# %%
k = 1.2
n_replicas = 3
n_samples = 4
swap_algorithm = {
	"p_ratio" : "p",
	"even": [90, 80, 70, 60],
	"odd":  [89, 79, 69, 59],
	"debug" : False
}

# %% [markdown]
# # Composed Dataset

# %%
# _ = plot_temperature_triptych(
# 	dataset_name="composed",
# 	k=k,
# 	n_samples=n_samples,
# 	n_replicas=n_replicas,
# 	replica_swaps=True,
# 	swap_algorithm=swap_algorithm
# )

# %%
# _ = plot_temperature_triptych(
# 	dataset_name="composed",
# 	k=k,
# 	n_samples=n_samples,
# 	n_replicas=n_replicas,
# 	replica_swaps=False,
# 	swap_algorithm=swap_algorithm
# )

# %% [markdown]
# # MNIST Dataset

# %%
# _ = plot_temperature_triptych(
# 	dataset_name="mnist",
# 	k=0.5,
# 	n_samples=n_samples,
# 	n_replicas=n_replicas,
# 	replica_swaps=False,
# 	swap_algorithm=swap_algorithm
# )

# %%
# _ = plot_temperature_triptych(
# 	dataset_name="mnist",
# 	k=2.0,
# 	n_samples=n_samples,
# 	n_replicas=n_replicas,
# 	replica_swaps=False,
# 	swap_algorithm=swap_algorithm
# )

# %% [markdown]
# # Best of N

# %%
_ = plot_temperature_triptych(
	dataset_name="composed",
	k=k,
	n_samples=n_samples,
	n_replicas=n_replicas,
	replica_swaps=True,
	swap_algorithm=swap_algorithm,
	best_of_n_runs=4
)
# Out:
# Running best-of-4...
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 _ = plot_temperature_triptych(
#       2 	dataset_name="composed",
#       3 	k=k,
#       4 	n_samples=n_samples,
#       5 	n_replicas=n_replicas,
#       6 	replica_swaps=True,
#       7 	swap_algorithm=swap_algorithm,
#       8 	best_of_n_runs=4
#       9 )
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/eval.py:56, in plot_temperature_triptych(dataset_name, k, n_samples, n_replicas, replica_swaps, swap_algorithm, x_limit, n_bins, best_of_n_runs)
#      54 if best_of_n_runs > 1 and dataset_name in DATASETS:
#      55 	print(f"Running best-of-{best_of_n_runs}...")
# ---> 56 	samples_ladder, best_score, all_scores = best_of_n(
#      57 		model=model,
#      58 		dataset_config=dataset_config,
#      59 		k=k,
#      60 		k_ladder=k_ladder,
#      61 		n_samples=best_of_n_runs,
#      62 		swap_algorithm=swap_algorithm,
#      63 		replica_swaps=replica_swaps,
#      64 	)
#      65 	print(f"Best score: {best_score:.4f} | All scores: {[f'{s:.4f}' for s in all_scores]}")
#      66 else:
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/best_of_n.py:34, in best_of_n(model, dataset_config, k, k_ladder, n_samples, swap_algorithm, replica_swaps)
#      31 torch.manual_seed(n)
#      32 np.random.seed(n)
# ---> 34 x_ladder = ddpm_tsr_swapped(
#      35     model=model,
#      36     dataset_shape=shape,
#      37     k=k,
#      38     k_ladder=k_ladder,
#      39     replica_swaps=replica_swaps,
#      40     swap_algorithm=swap_algorithm,
#      41 )
#      43 # Use k=1.0 replica as candidate
#      44 x_candidate = x_ladder[k]  # [N, 1]
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/sample.py:74, in ddpm_tsr_swapped(model, dataset_shape, k, k_ladder, replica_swaps, swap_algorithm)
#      71 		x_ladder[k_val] = x.clone()
#      73 	if replica_swaps:
# ---> 74 		x_ladder = replica_exchange(model, t, k, k_ladder, x_ladder, swap_algorithm)
#      76 return x_ladder
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/sample.py:44, in replica_exchange(model, t, k, k_ladder, x_ladder, swap_algorithm)
#      41 (x_t, k_t) = target
#      42 (x_s, k_s) = source
# ---> 44 accept_mask = compute_correction(model, target, source, t, swap_algorithm)
#      46 if swap_algorithm["debug"]: print(f"Time {t} swap btwn source {k_s.item():.2f} and target {k_t.item():.2f} accept {accept_mask.sum().item() / 100_000 :.2f} ")
#      48 x_ladder[k_t] = accept_mask * x_s + (1 - accept_mask) * x_t
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/score_integral.py:124, in compute_correction(model, target, source, t, swap_algorithm)
#     121 x_t, k_t = target
#     122 x_s, k_s = source
# --> 124 f = compute_score_integral(model, target, source, t, swap_algorithm)
#     125 a = torch.clamp(torch.exp(f), max = 1.0)
#     127 if swap_algorithm["debug"]:
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/score_integral.py:72, in compute_score_integral(model, target, source, t, swap_algorithm, second_energy, n_segments)
#      68 n_seg, _, D = r.shape
#      70 r_in = r.reshape(n_seg * bs, *original_shape[1:])
# ---> 72 score = compute_score(model, r_in, t, 1.0).reshape(n_seg, bs, D)
#      74 integrand = score * r_deriv
#      76 f_flat = torch.trapz(integrand, s, dim=0)            # (bs, D)
#
# File ~/.local/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/model.py:145, in compute_score(model, x, t, k)
#     142 ones = torch.ones((x_shape[0], 1), device=device)
#     143 a_bar = alpha_bars[t]
# --> 145 eps_hat = model(x, t * ones)
#     146 temp_t = compute_tsr_schedule(k, t)
#     148 return - eps_hat * temp_t / torch.sqrt(1.0 - a_bar)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/model.py:54, in MLP.forward(self, x, t)
#      52 t_emb = self.time_embed(t)
#      53 h = torch.cat([x, t_emb], dim=-1)
# ---> 54 h = F.silu(self.input(h))
#      55 for layer in self.layers:
#      56 	h = h + F.silu(layer(h))
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/.local/lib/python3.12/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 1.53 GiB. GPU 0 has a total capacity of 19.62 GiB of which 523.31 MiB is free. Process 99528 has 18.36 GiB memory in use. Including non-PyTorch memory, this process has 652.00 MiB memory in use. Of the allocated memory 423.23 MiB is allocated by PyTorch, and 12.77 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

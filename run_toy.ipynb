# %% [markdown]
# # Computing Tempered Energy

# %% [markdown]
# We aim to implement a parallel tempering scheme for annealed MCMC as per Du et al.'s [2024 paper](https://arxiv.org/pdf/2302.11552) on compositional generation with energy-based diffusion. In order to implement parallel tempering into the sampling regime of annealed MCMC, we aim to evaluate the difference between true tempered energy and our approximations.
#
# Training follows standard DDPM noise-matching objective

# %% [markdown]
# ### Setup

# %%
from src.eval import plot_temperature_triptych
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.eval import plot_temperature_triptych
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/eval.py:5
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 5 from .model import load_model
#       6 from .dataset import compute_mixture_pdf
#       7 from .config import DEVICE, DATASETS, DATASETS_IMG, CKPT_DIR, N_DIFFUSION_STEPS
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/model.py:5
#       3 import torch.nn.functional as F
#       4 import math
# ----> 5 from .schedule import betas, alphas, alpha_bars, ts_desc, compute_tsr_schedule
#       7 from .config import DATASETS, DATASETS_IMG, DEVICE
#       9 torch.manual_seed(42)
#
# File /n/netscratch/kempner_undergrads/Everyone/zwu/parallel_toy/src/schedule.py:20
#      17 	betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
#      18 	return torch.clip(betas, 0, 0.999)
# ---> 20 betas = cosine_beta_schedule(n_diffusion_steps).to(device)
#      21 alphas = 1.0 - betas
#      22 alpha_bars = torch.cumprod(alphas, dim=0)  # alphā_t
#
# RuntimeError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
k = 1.2
n_replicas = 3
n_samples = 4
swap_algorithm = {
	"p_ratio" : "p",
	"even": [90, 80, 70, 60],
	"odd":  [89, 79, 69, 59],
	"debug" : False
}

# %% [markdown]
# # Composed Dataset

# %%
_ = plot_temperature_triptych(
	dataset_name="composed",
	k=k,
	n_samples=n_samples,
	n_replicas=n_replicas,
	replica_swaps=True,
	swap_algorithm=swap_algorithm
)

# %%
# _ = plot_temperature_triptych(
# 	dataset_name="composed",
# 	k=k,
# 	n_samples=n_samples,
# 	n_replicas=n_replicas,
# 	replica_swaps=False,
# 	swap_algorithm=swap_algorithm
# )

# %% [markdown]
# # MNIST Dataset

# %%
# _ = plot_temperature_triptych(
# 	dataset_name="mnist",
# 	k=0.5,
# 	n_samples=n_samples,
# 	n_replicas=n_replicas,
# 	replica_swaps=False,
# 	swap_algorithm=swap_algorithm
# )

# %%
# _ = plot_temperature_triptych(
# 	dataset_name="mnist",
# 	k=2.0,
# 	n_samples=n_samples,
# 	n_replicas=n_replicas,
# 	replica_swaps=False,
# 	swap_algorithm=swap_algorithm
# )
